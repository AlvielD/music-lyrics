# %%
import utils

# %%
utils.get_song_id_by_artist_title("Lady Gaga", "Marry The Night", "./conversion/id.txt")
# Out:
# '00000646'

# %%
utils.get_all_song_ids_by_artist("Lady Gaga", "./conversion/id.txt")
# Out:
# ['00000180',
#  '000004EC',
#  '00000646',
#  '000007A1',
#  '0000099E',
#  '000009F9',
#  '00000B29',
#  '00000CE4']

# %%
utils.get_all_songs_by_artist("Lady Gaga", "./conversion/id.txt")
# Out:
# ['Fashion Of His Love',
#  'Paper Gangsta',
#  'Marry The Night',
#  "Stuck On Fuckin' You",
#  'Donatella',
#  'Venus',
#  'The Queen',
#  'Dope']

# %%
utils.print_file_content("./conversion/saved/00000645.json")
# Out:
# {
#     "meta": {
#         "song_id": "00000645",
#         "title": "Marry The Night",
#         "artist": "Lady Gaga",
#         "language": "en"
#     },
#     "annotations": [
#         {
#             "paragraph": "Verse",
#             "occurrence": 1,
#             "time_index": [
#                 1.1579999999999995,
#                 40.76724979012442
#             ],
#             "time_duration": 39.609249790124416,
#             "singer": [
#                 "Lady Gaga"
#             ],
#             "lines": [
#                 {
#                     "line": "i'm gonna marry the night",
#                     "time_index": [
#                         1.1579999999999995,
#                         4.0771788140120595
#                     ],
#                     "time_duration": 2.91917881401206
#                 },
#                 {
#                     "line": "i won't give up on my life",
#                     "time_index": [
# ...
