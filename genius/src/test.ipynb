# %%
import requests
import utils
import pprint
import config

# %%
# Example usage
song_title = 'Bohemian Rhapsody'
song = utils.search_song(song_title)

# %%
song
# Out:
# {'annotation_count': 26,
#  'api_path': '/songs/1063',
#  'artist_names': 'Queen',
#  'full_title': 'Bohemian Rhapsody by\xa0Queen',
#  'header_image_thumbnail_url': 'https://images.genius.com/718de9d1fbcaae9f3c9b1bf483bfa8f1.300x300x1.png',
#  'header_image_url': 'https://images.genius.com/718de9d1fbcaae9f3c9b1bf483bfa8f1.1000x1000x1.png',
#  'id': 1063,
#  'lyrics_owner_id': 3,
#  'lyrics_state': 'complete',
#  'path': '/Queen-bohemian-rhapsody-lyrics',
#  'primary_artist_names': 'Queen',
#  'pyongs_count': 695,
#  'relationships_index_url': 'https://genius.com/Queen-bohemian-rhapsody-sample',
#  'release_date_components': {'year': 1975, 'month': 10, 'day': 31},
#  'release_date_for_display': 'October 31, 1975',
#  'release_date_with_abbreviated_month_for_display': 'Oct. 31, 1975',
#  'song_art_image_thumbnail_url': 'https://images.genius.com/718de9d1fbcaae9f3c9b1bf483bfa8f1.300x300x1.png',
# ...

# %%
# Example usage
song_title = 'Bohemian Rhapsody'
song = utils.search_song(song_title)

if song:
    song_id = song['id']
    song_metadata = get_song_metadata(song_id)
    pprint.pprint(song_metadata)
else:
    print('Song not found.')
# Out:
# {'meta': {'status': 200},
#  'response': {'song': {'album': {'api_path': '/albums/35169',
#                                  'artist': {'api_path': '/artists/563',
#                                             'header_image_url': 'https://images.genius.com/e7f111196181f254d6f1ea90a46cd308.999x425x1.jpg',
#                                             'id': 563,
#                                             'image_url': 'https://images.genius.com/3bc047e8b3c654ed28aedc69f93f8663.1000x1000x1.jpg',
#                                             'is_meme_verified': False,
#                                             'is_verified': False,
#                                             'name': 'Queen',
#                                             'url': 'https://genius.com/artists/Queen'},
#                                  'cover_art_url': 'https://images.genius.com/bc1d2e0fd77810ed54ee87646eba720c.1000x1000x1.png',
# ...
